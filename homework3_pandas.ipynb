# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# получить доступ к данным из задания 2
data_homework = pd.read_csv('homework3_data.csv')

# %%
# построить 3D представление данных
np.random.seed(123)

x = np.random.randint(-5, 5, 40)
y = np.random.randint(0, 10, 40)
z = np.random.randint(-5, 5, 40)
s = np.random.randint(10, 100, 40)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, s=s)
